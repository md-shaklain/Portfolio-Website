# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Videos\OneDrive\Desktop\Python full stack\pandas\Salesman.csv")
df
# Out:
#           Product    Sales Person                              Dealer Region  \
# 0            Bike  BHALCHANDRA D.         MAHINDRA CIE AUTOMOTIVE LTD   East
# 1      Motor Bike     LALCHAND M.            AUTOMOTIVE STAMPINGS LTD   West
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3            Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4   Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5     Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7      Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8           Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9            Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# ...

# %%
df.tail()
# Out:
#           Product Sales Person                            Dealer Region  \
# 25     Motor Bike     MANOJ T.  BHAGWAT AUTOSERVICES PRIVATE LTD   West
# 26          Cycle  PRAFULLA H.       MAHINDRA CIE AUTOMOTIVE LTD  North
# 27           Auto    YOGESH T.          AUTOMOTIVE STAMPINGS LTD  South
# 28  Electric Bike     RAHUL R.        G. G. AUTOMOTIVE GEARS LTD   East
# 29    Sports Bike    SONIYA S.    HONEYWELL AUTOMATION INDIA LTD   West
#
#     Y 2009  Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 25   33068   16383   82665   96389   76197   89337   49845   77522
# 26   12778   81623   31198   24385   39944   10655   11378   37786
# 27   13075   99673   88847   23225   83198   16152   94377   51949
# 28   79843   56724   56030   77407   27193   89056   27061   42167
# 29   18425   60222   67126   61478   25049   22538   53862   16669

# %%
df.head(10)
# Out:
#          Product    Sales Person                              Dealer Region  \
# 0           Bike  BHALCHANDRA D.         MAHINDRA CIE AUTOMOTIVE LTD   East
# 1     Motor Bike     LALCHAND M.            AUTOMOTIVE STAMPINGS LTD   West
# 2          Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3           Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4  Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5    Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6           Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7     Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8          Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9           Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
#
#    Y 2009  Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 0   49887   52615   48841   74134   98066   95563   23428   57554
# ...

# %%
df.shape
# Out:
# (30, 12)

# %%
df.shape[0]
# Out:
# 30

# %%
df.shape[1]
# Out:
# 12

# %%
df.columns
# Out:
# Index(['Product', 'Sales Person', 'Dealer', 'Region', 'Y 2009', 'Y 2010',
#        'Y 2011', 'Y 2012', 'Y 2013', 'Y 2014', 'Y 2015', 'Y 2016'],
#       dtype='object')

# %%
df.columns[0:3]
# Out:
# Index(['Product', 'Sales Person', 'Dealer'], dtype='object')

# %%
df.dtypes
# Out:
# Product         object
# Sales Person    object
# Dealer          object
# Region          object
# Y 2009           int64
# Y 2010           int64
# Y 2011           int64
# Y 2012           int64
# Y 2013           int64
# Y 2014           int64
# Y 2015           int64
# Y 2016           int64
# dtype: object

# %%
df['Y 2014'].dtypes
# Out:
# dtype('int64')

# %%
df['Y 2009']=df['Y 2009'].astype(float)
df
# Out:
#           Product    Sales Person                              Dealer Region  \
# 0            Bike  BHALCHANDRA D.         MAHINDRA CIE AUTOMOTIVE LTD   East
# 1      Motor Bike     LALCHAND M.            AUTOMOTIVE STAMPINGS LTD   West
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3            Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4   Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5     Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7      Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8           Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9            Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# ...

# %%
df['Y 2009'].dtypes
# Out:
# dtype('float64')

# %%
df1 =df[df.Region=='North']
df1
# Out:
#           Product    Sales Person                              Dealer Region  \
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# 14          Cycle        MANOJ T.            AUTOMOTIVE STAMPINGS LTD  North
# 18           Bike       SONIYA S.  AUTOMOBILE DEALERS ASSOCIATION LTD  North
# 22  Electric Bike  BHALCHANDRA D.                     BAJAJ AUTO LTD.  North
# 26          Cycle     PRAFULLA H.         MAHINDRA CIE AUTOMOTIVE LTD  North
#
#      Y 2009  Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 2   26497.0   28845   22449   55384   21829   40624   13215   68100
# 6   41862.0   60493   33085   17529   49219   67081   15946   20268
# 10  19766.0   84782   88562   23081   94641   47877   42589   46000
# 14  37301.0   13557   92082   68180   30558   86252   32171   73626
# ...

# %%
df.isnull().sum()
# Out:
# Product         0
# Sales Person    0
# Dealer          0
# Region          0
# Y 2009          0
# Y 2010          0
# Y 2011          0
# Y 2012          0
# Y 2013          0
# Y 2014          0
# Y 2015          0
# Y 2016          0
# dtype: int64

# %%
df['Y 2011']=df['Y 2011'].astype(float)
df
# Out:
#           Product    Sales Person                              Dealer Region  \
# 0            Bike  BHALCHANDRA D.         MAHINDRA CIE AUTOMOTIVE LTD   East
# 1      Motor Bike     LALCHAND M.            AUTOMOTIVE STAMPINGS LTD   West
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3            Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4   Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5     Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7      Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8           Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9            Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# ...

# %%
df.head()
# Out:
#          Product    Sales Person                          Dealer Region  \
# 0           Bike  BHALCHANDRA D.     MAHINDRA CIE AUTOMOTIVE LTD   East
# 1     Motor Bike     LALCHAND M.        AUTOMOTIVE STAMPINGS LTD   West
# 2          Cycle   MACHHINDRA B.      G. G. AUTOMOTIVE GEARS LTD  North
# 3           Auto        MANOJ T.  HONEYWELL AUTOMATION INDIA LTD  South
# 4  Electric Bike     PRAFULLA H.     LUMAX AUTO TECHNOLOGIES LTD   East
#
#    Y 2009  Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 0   49887   52615   48841   74134   98066   95563   23428   57554
# 1   24605   24065   92912   49548   58276   26590   15096   38605
# 2   26497   28845   22449   55384   21829   40624   13215   68100
# 3   58213   68168   85206   23603   53044   22524   94037   21543
# 4   92382   12708   88414   53404   42964   47582   39632   53349

# %%
df.dtypes
# Out:
# Product         object
# Sales Person    object
# Dealer          object
# Region          object
# Y 2009           int64
# Y 2010           int64
# Y 2011           int64
# Y 2012           int64
# Y 2013           int64
# Y 2014           int64
# Y 2015           int64
# Y 2016           int64
# dtype: object

# %%
df1= df[df.Region=='South']
df1
# Out:
#         Product    Sales Person                          Dealer Region  \
# 3          Auto        MANOJ T.  HONEYWELL AUTOMATION INDIA LTD  South
# 7    Motor Bike       SONIYA S.         AUTOLINE INDUSTRIES LTD  South
# 11  Sports Bike  BHALCHANDRA D.         BRAKES AUTO (INDIA) LTD  South
# 15         Auto     PRAFULLA H.      G. G. AUTOMOTIVE GEARS LTD  South
# 19   Motor Bike        DIPAK R.      NISCO AUTO CORPORATION LTD  South
# 23  Sports Bike     LALCHAND M.    AUTORIDERS INTERNATIONAL LTD  South
# 27         Auto       YOGESH T.        AUTOMOTIVE STAMPINGS LTD  South
#
#     Y 2009  Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 3    58213   68168   85206   23603   53044   22524   94037   21543
# 7    62693   32312   67361   88494   23610   18663   94987   17650
# 11   72213   45261   19198   88035   75080   70661   88140   95241
# 15   28340   41638   35810   19921   99487   97919   60994   22385
# ...

# %%
df['Y 2011'].dtypes
# Out:
# dtype('int64')

# %%
df['Dealer']
# Out:
# 0            MAHINDRA CIE AUTOMOTIVE LTD
# 1               AUTOMOTIVE STAMPINGS LTD
# 2             G. G. AUTOMOTIVE GEARS LTD
# 3         HONEYWELL AUTOMATION INDIA LTD
# 4            LUMAX AUTO TECHNOLOGIES LTD
# 5     AUTOMOBILE DEALERS ASSOCIATION LTD
# 6             NISCO AUTO CORPORATION LTD
# 7                AUTOLINE INDUSTRIES LTD
# 8                 AUTORIDERS FINANCE LTD
# 9                        BAJAJ AUTO LTD.
# 10          AUTORIDERS INTERNATIONAL LTD
# 11               BRAKES AUTO (INDIA) LTD
# 12      BHAGWAT AUTOSERVICES PRIVATE LTD
# 13           MAHINDRA CIE AUTOMOTIVE LTD
# 14              AUTOMOTIVE STAMPINGS LTD
# 15            G. G. AUTOMOTIVE GEARS LTD
# 16        HONEYWELL AUTOMATION INDIA LTD
# 17           LUMAX AUTO TECHNOLOGIES LTD
# 18    AUTOMOBILE DEALERS ASSOCIATION LTD
# 19            NISCO AUTO CORPORATION LTD
# 20               AUTOLINE INDUSTRIES LTD
# 21                AUTORIDERS FINANCE LTD
# 22                       BAJAJ AUTO LTD.
# ...

# %%
df['Product']
# Out:
# 0              Bike
# 1        Motor Bike
# 2             Cycle
# 3              Auto
# 4     Electric Bike
# 5       Sports Bike
# 6              Bike
# 7        Motor Bike
# 8             Cycle
# 9              Auto
# 10    Electric Bike
# 11      Sports Bike
# 12             Bike
# 13       Motor Bike
# 14            Cycle
# 15             Auto
# 16    Electric Bike
# 17      Sports Bike
# 18             Bike
# 19       Motor Bike
# 20            Cycle
# 21             Auto
# 22    Electric Bike
# 23      Sports Bike
# 24             Bike
# 25       Motor Bike
# 26            Cycle
# 27             Auto
# 28    Electric Bike
# 29      Sports Bike
# Name: Product, dtype: object

# %%
df.isnull().sum()
# Out:
# Product         0
# Sales Person    0
# Dealer          0
# Region          0
# Y 2009          0
# Y 2010          0
# Y 2011          0
# Y 2012          0
# Y 2013          0
# Y 2014          0
# Y 2015          0
# Y 2016          0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#        Product    Sales Person                       Dealer Region
# count       30              30                           30     30
# unique       6              11                           13      4
# top       Bike  BHALCHANDRA D.  MAHINDRA CIE AUTOMOTIVE LTD   East
# freq         5               3                            3      8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product       30 non-null     object
#  1   Sales Person  30 non-null     object
#  2   Dealer        30 non-null     object
#  3   Region        30 non-null     object
#  4   Y 2009        30 non-null     int64
#  5   Y 2010        30 non-null     int64
#  6   Y 2011        30 non-null     int64
#  7   Y 2012        30 non-null     int64
#  8   Y 2013        30 non-null     int64
#  9   Y 2014        30 non-null     int64
#  10  Y 2015        30 non-null     int64
#  11  Y 2016        30 non-null     int64
# dtypes: int64(8), object(4)
# memory usage: 2.9+ KB

# %%
df.Product.unique()
# Out:
# array(['Bike', 'Motor Bike', 'Cycle', 'Auto', 'Electric Bike',
#        'Sports Bike'], dtype=object)

# %%
df3=df.sample(n=7)
df3
# Out:
#           Product   Sales Person                        Dealer Region  Y 2009  \
# 1      Motor Bike    LALCHAND M.      AUTOMOTIVE STAMPINGS LTD   West   24605
# 13     Motor Bike  MACHHINDRA B.   MAHINDRA CIE AUTOMOTIVE LTD   West   77660
# 27           Auto      YOGESH T.      AUTOMOTIVE STAMPINGS LTD  South   13075
# 10  Electric Bike     SANDESH J.  AUTORIDERS INTERNATIONAL LTD  North   19766
# 20          Cycle     PRADEEP M.       AUTOLINE INDUSTRIES LTD   East   39716
# 24           Bike  MACHHINDRA B.       BRAKES AUTO (INDIA) LTD   East   14992
# 9            Auto     PRADEEP M.               BAJAJ AUTO LTD.   West   61179
#
#     Y 2010  Y 2011  Y 2012  Y 2013  Y 2014  Y 2015  Y 2016
# 1    24065   92912   49548   58276   26590   15096   38605
# 13   85172   98873   28706   37804   60680   71748   98585
# 27   99673   88847   23225   83198   16152   94377   51949
# 10   84782   88562   23081   94641   47877   42589   46000
# ...

# %%
df4=df.drop([0,1],axis=0)
df4
# Out:
#           Product    Sales Person                              Dealer Region  \
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3            Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4   Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5     Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7      Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8           Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9            Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# 11    Sports Bike  BHALCHANDRA D.             BRAKES AUTO (INDIA) LTD  South
# 12           Bike     LALCHAND M.    BHAGWAT AUTOSERVICES PRIVATE LTD   East
# ...

# %%
df
# Out:
#           Product    Sales Person                              Dealer Region  \
# 0            Bike  BHALCHANDRA D.         MAHINDRA CIE AUTOMOTIVE LTD   East
# 1      Motor Bike     LALCHAND M.            AUTOMOTIVE STAMPINGS LTD   West
# 2           Cycle   MACHHINDRA B.          G. G. AUTOMOTIVE GEARS LTD  North
# 3            Auto        MANOJ T.      HONEYWELL AUTOMATION INDIA LTD  South
# 4   Electric Bike     PRAFULLA H.         LUMAX AUTO TECHNOLOGIES LTD   East
# 5     Sports Bike       YOGESH T.  AUTOMOBILE DEALERS ASSOCIATION LTD   West
# 6            Bike        RAHUL R.          NISCO AUTO CORPORATION LTD  North
# 7      Motor Bike       SONIYA S.             AUTOLINE INDUSTRIES LTD  South
# 8           Cycle        DIPAK R.              AUTORIDERS FINANCE LTD   East
# 9            Auto      PRADEEP M.                     BAJAJ AUTO LTD.   West
# 10  Electric Bike      SANDESH J.        AUTORIDERS INTERNATIONAL LTD  North
# ...

# %%
df['Product']
# Out:
# 0              Bike
# 1        Motor Bike
# 2             Cycle
# 3              Auto
# 4     Electric Bike
# 5       Sports Bike
# 6              Bike
# 7        Motor Bike
# 8             Cycle
# 9              Auto
# 10    Electric Bike
# 11      Sports Bike
# 12             Bike
# 13       Motor Bike
# 14            Cycle
# 15             Auto
# 16    Electric Bike
# 17      Sports Bike
# 18             Bike
# 19       Motor Bike
# 20            Cycle
# 21             Auto
# 22    Electric Bike
# 23      Sports Bike
# 24             Bike
# 25       Motor Bike
# 26            Cycle
# 27             Auto
# 28    Electric Bike
# 29      Sports Bike
# Name: Product, dtype: object
